# %%
from Bio.Seq import Seq

file = open("rosalind_prot.txt", "r")
seq = Seq(file.read())
prot = seq.translate()
print(prot)
# Out:
# ...*
# /home/banada/miniconda3/envs/bioinformatics/lib/python3.9/site-packages/Bio/Seq.py:2334: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   warnings.warn(
